# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import Subset
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as utils
from IPython.display import HTML
import time
from torchvision import models
import torch.nn.functional as F
from scipy import linalg

# %%
dataset = datasets.CIFAR10(root="/Users/sandeepvarmasangaraju/Downloads", download=False,
                           transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))

dataloader = torch.utils.data.DataLoader(dataset, batch_size=32,
                                         shuffle=True, num_workers=2)

device = torch.device("cuda")

# %%
real_batch = next(iter(dataloader))
plt.figure(figsize=(10,10))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            # input: N x channels_img x 64 x 64
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),
            nn.LeakyReLU(0.2),
            # _block(in_channels, out_channels, kernel_size, stride, padding)
            self._block(features_d, features_d * 2, 4, 2, 1),
            self._block(features_d * 2, features_d * 4, 4, 2, 1),
            self._block(features_d * 4, features_d * 8, 4, 2, 1),
            # After all _block img output is 4x4 (Conv2d below makes into 1x1)
            nn.Conv2d(features_d * 8, 1, kernel_size=4, stride=2, padding=0),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.InstanceNorm2d(out_channels, affine=True),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.disc(x)

# %%
class Generator(nn.Module):
    def __init__(self, channels_noise, channels_img, features_g):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            # Input: N x channels_noise x 1 x 1
            self._block(channels_noise, features_g * 16, 4, 1, 0),  # img: 4x4
            self._block(features_g * 16, features_g * 8, 4, 2, 1),  # img: 8x8
            self._block(features_g * 8, features_g * 4, 4, 2, 1),  # img: 16x16
            self._block(features_g * 4, features_g * 2, 4, 2, 1),  # img: 32x32
            nn.ConvTranspose2d(
                features_g * 2, channels_img, kernel_size=4, stride=2, padding=1
            ),
            # Output: N x channels_img x 64 x 64
            nn.Tanh(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %%
def initialize_weights(model):
    # Initializes weights according to the DCGAN paper
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
class InceptionV3(nn.Module):
    """Pretrained InceptionV3 network returning feature maps"""

    # Index of default block of inception to return,
    # corresponds to output of final average pooling
    DEFAULT_BLOCK_INDEX = 3

    # Maps feature dimensionality to their output blocks indices
    BLOCK_INDEX_BY_DIM = {
        64: 0,
        192: 1,
        768: 2,
        2048: 3
    }

    def __init__(self,
                 output_blocks=[DEFAULT_BLOCK_INDEX],
                 resize_input=True,
                 normalize_input=True,
                 requires_grad=False):
        
        super(InceptionV3, self).__init__()

        self.resize_input = resize_input
        self.normalize_input = normalize_input
        self.output_blocks = sorted(output_blocks)
        self.last_needed_block = max(output_blocks)

        assert self.last_needed_block <= 3, \
            'Last possible output block index is 3'

        self.blocks = nn.ModuleList()

        
        inception = models.inception_v3(pretrained=True)

        # Block 0: input to maxpool1
        block0 = [
            inception.Conv2d_1a_3x3,
            inception.Conv2d_2a_3x3,
            inception.Conv2d_2b_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2)
        ]
        self.blocks.append(nn.Sequential(*block0))

        # Block 1: maxpool1 to maxpool2
        if self.last_needed_block >= 1:
            block1 = [
                inception.Conv2d_3b_1x1,
                inception.Conv2d_4a_3x3,
                nn.MaxPool2d(kernel_size=3, stride=2)
            ]
            self.blocks.append(nn.Sequential(*block1))

        # Block 2: maxpool2 to aux classifier
        if self.last_needed_block >= 2:
            block2 = [
                inception.Mixed_5b,
                inception.Mixed_5c,
                inception.Mixed_5d,
                inception.Mixed_6a,
                inception.Mixed_6b,
                inception.Mixed_6c,
                inception.Mixed_6d,
                inception.Mixed_6e,
            ]
            self.blocks.append(nn.Sequential(*block2))

        # Block 3: aux classifier to final avgpool
        if self.last_needed_block >= 3:
            block3 = [
                inception.Mixed_7a,
                inception.Mixed_7b,
                inception.Mixed_7c,
                nn.AdaptiveAvgPool2d(output_size=(1, 1))
            ]
            self.blocks.append(nn.Sequential(*block3))

        for param in self.parameters():
            param.requires_grad = requires_grad

    def forward(self, inp):
        outp = []
        x = inp

        if self.resize_input:
            x = F.interpolate(x,
                              size=(299, 299),
                              mode='bilinear',
                              align_corners=False)

        if self.normalize_input:
            x = 2 * x - 1  # Scale from range (0, 1) to range (-1, 1)

        for idx, block in enumerate(self.blocks):
            x = block(x)
            if idx in self.output_blocks:
                outp.append(x)

            if idx == self.last_needed_block:
                break

        return outp
    
block_idx = InceptionV3.BLOCK_INDEX_BY_DIM[2048]
model = InceptionV3([block_idx])
model=model.cuda()

# %%
def calculate_activation_statistics(images, model, batch_size=128, dims=2048, cuda=False):
    model.eval()
    act=np.empty((len(images), dims))
    
    if cuda:
        batch=images.cuda()
    else:
        batch=images
    pred = model(batch)[0]
    if pred.size(2) != 1 or pred.size(3) != 1:
        pred = adaptive_avg_pool2d(pred, output_size=(1, 1))

    act= pred.cpu().data.numpy().reshape(pred.size(0), -1)
    
    mu = np.mean(act, axis=0)
    sigma = np.cov(act, rowvar=False)
    return mu, sigma

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)

    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)

    assert mu1.shape == mu2.shape, \
        'Training and test mean vectors have different lengths'
    assert sigma1.shape == sigma2.shape, \
        'Training and test covariances have different dimensions'

    diff = mu1 - mu2

    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not np.isfinite(covmean).all():
        msg = ('fid calculation produces singular product; '
               'adding %s to diagonal of cov estimates') % eps
        print(msg)
        offset = np.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))

    
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real

    tr_covmean = np.trace(covmean)

    return (diff.dot(diff) + np.trace(sigma1) +
            np.trace(sigma2) - 2 * tr_covmean)

def calculate_fretchet(images_real,images_fake,model):
    mu_1,std_1 = calculate_activation_statistics(images_real,model,cuda=True)
    mu_2,std_2 = calculate_activation_statistics(images_fake,model,cuda=True)
    fid_value = calculate_frechet_distance(mu_1, std_1, mu_2, std_2)
    return fid_value

# %%
lr = 5e-5
Z_DIM = 128
num_epochs = 50
WEIGHT_CLIP = 0.01

# %%
gen = Generator(Z_DIM, channels_img = 3, features_g = 64).to(device)
critic = Discriminator(channels_img = 3, features_d = 64).to(device)
initialize_weights(gen)
initialize_weights(critic)

# %%
opt_gen = optim.RMSprop(gen.parameters(), lr = lr)
opt_critic = optim.RMSprop(critic.parameters(), lr = lr)

fixed_noise = torch.randn(32, Z_DIM, 1, 1).to(device)
step = 0

gen.train()
critic.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#   )
# )

# %%
GenLoss = []
DiscLoss = []
img_list = []
fretchet_distances = []
iters = 0

for epoch in range(num_epochs):
    # Target labels not needed! <3 unsupervised
    for batch_idx, (data, _) in enumerate(dataloader):
        data = data.to(device)
        cur_batch_size = data.shape[0]

        # Train Critic: max E[critic(real)] - E[critic(fake)]
        for _ in range(5): # 5 critic iterations
            noise = torch.randn(cur_batch_size, Z_DIM, 1, 1).to(device)
            fake = gen(noise)
            critic_real = critic(data).reshape(-1)
            critic_fake = critic(fake).reshape(-1)
            loss_critic = -(torch.mean(critic_real) - torch.mean(critic_fake))
            critic.zero_grad()
            loss_critic.backward(retain_graph=True)
            opt_critic.step()

            # clip critic weights between -0.01, 0.01
            for p in critic.parameters():
                p.data.clamp_(-WEIGHT_CLIP, WEIGHT_CLIP)

        # Train Generator: max E[critic(gen_fake)] <-> min -E[critic(gen_fake)]
        gen_fake = critic(fake).reshape(-1)
        loss_gen = -torch.mean(gen_fake)
        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()

        # Print losses occasionally
        if batch_idx % 100 == 0:
            print(
                f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(dataloader)} \
                  Loss Discriminator: {loss_critic:.3f}, loss Generator: {loss_gen:.3f}"
            )
        #saving the losses for every 100 batch
        GenLoss.append(loss_gen.detach().cpu())
        DiscLoss.append(loss_critic.detach().cpu())
        
        # Check how the generator is doing by saving G's output on fixed_noise
        if (iters % 500 == 0) or ((epoch == num_epochs) and (batch_idx == len(dataloader)-1)):
            with torch.no_grad():
                fake = gen(fixed_noise).detach().cpu()
            img_list.append(utils.make_grid(fake, padding=2, normalize=True))
            
        iters += 1
    fretchet_dist = calculate_fretchet(data, fake, model)
    fretchet_distances.append(fretchet_dist)
    print('Fretchet Distance: ', fretchet_dist)
# Out:
# Epoch [0/50] Batch 0/1563                   Loss Discriminator: -0.017, loss Generator: 0.009
# Epoch [0/50] Batch 100/1563                   Loss Discriminator: -1.326, loss Generator: 0.661
# Epoch [0/50] Batch 200/1563                   Loss Discriminator: -1.532, loss Generator: 0.761
# Epoch [0/50] Batch 300/1563                   Loss Discriminator: -1.550, loss Generator: 0.769
# Epoch [0/50] Batch 400/1563                   Loss Discriminator: -1.546, loss Generator: 0.767
# Epoch [0/50] Batch 500/1563                   Loss Discriminator: -1.514, loss Generator: 0.756
# Epoch [0/50] Batch 600/1563                   Loss Discriminator: -1.505, loss Generator: 0.752
# Epoch [0/50] Batch 700/1563                   Loss Discriminator: -1.469, loss Generator: 0.731
# Epoch [0/50] Batch 800/1563                   Loss Discriminator: -1.461, loss Generator: 0.736
# Epoch [0/50] Batch 900/1563                   Loss Discriminator: -1.378, loss Generator: 0.712
# Epoch [0/50] Batch 1000/1563                   Loss Discriminator: -1.346, loss Generator: 0.708
# Epoch [0/50] Batch 1100/1563                   Loss Discriminator: -1.285, loss Generator: 0.661
# Epoch [0/50] Batch 1200/1563                   Loss Discriminator: -1.251, loss Generator: 0.647
# Epoch [0/50] Batch 1300/1563                   Loss Discriminator: -1.254, loss Generator: 0.677
# Epoch [0/50] Batch 1400/1563                   Loss Discriminator: -1.168, loss Generator: 0.654
# Epoch [0/50] Batch 1500/1563                   Loss Discriminator: -1.089, loss Generator: 0.537
# Fretchet Distance:  357.42609035381315
# Epoch [1/50] Batch 0/1563                   Loss Discriminator: -1.086, loss Generator: 0.507
# Epoch [1/50] Batch 100/1563                   Loss Discriminator: -1.092, loss Generator: 0.556
# Epoch [1/50] Batch 200/1563                   Loss Discriminator: -1.129, loss Generator: 0.500
# Epoch [1/50] Batch 300/1563                   Loss Discriminator: -1.112, loss Generator: 0.539
# Epoch [1/50] Batch 400/1563                   Loss Discriminator: -1.124, loss Generator: 0.547
# Epoch [1/50] Batch 500/1563                   Loss Discriminator: -1.005, loss Generator: 0.498
# Epoch [1/50] Batch 600/1563                   Loss Discriminator: -1.076, loss Generator: 0.514
# Epoch [1/50] Batch 700/1563                   Loss Discriminator: -0.879, loss Generator: 0.428
# Epoch [1/50] Batch 800/1563                   Loss Discriminator: -1.019, loss Generator: 0.621
# Epoch [1/50] Batch 900/1563                   Loss Discriminator: -1.040, loss Generator: 0.651
# Epoch [1/50] Batch 1000/1563                   Loss Discriminator: -1.106, loss Generator: 0.511
# Epoch [1/50] Batch 1100/1563                   Loss Discriminator: -1.077, loss Generator: 0.547
# Epoch [1/50] Batch 1200/1563                   Loss Discriminator: -1.025, loss Generator: 0.518
# Epoch [1/50] Batch 1300/1563                   Loss Discriminator: -1.139, loss Generator: 0.574
# Epoch [1/50] Batch 1400/1563                   Loss Discriminator: -0.998, loss Generator: 0.627
# Epoch [1/50] Batch 1500/1563                   Loss Discriminator: -0.982, loss Generator: 0.584
# Fretchet Distance:  330.2060508687965
# Epoch [2/50] Batch 0/1563                   Loss Discriminator: -0.898, loss Generator: 0.607
# Epoch [2/50] Batch 100/1563                   Loss Discriminator: -0.978, loss Generator: 0.404
# Epoch [2/50] Batch 200/1563                   Loss Discriminator: -0.979, loss Generator: 0.418
# Epoch [2/50] Batch 300/1563                   Loss Discriminator: -1.021, loss Generator: 0.428
# Epoch [2/50] Batch 400/1563                   Loss Discriminator: -0.988, loss Generator: 0.439
# Epoch [2/50] Batch 500/1563                   Loss Discriminator: -0.971, loss Generator: 0.562
# Epoch [2/50] Batch 600/1563                   Loss Discriminator: -1.005, loss Generator: 0.621
# Epoch [2/50] Batch 700/1563                   Loss Discriminator: -0.867, loss Generator: 0.629
# Epoch [2/50] Batch 800/1563                   Loss Discriminator: -1.021, loss Generator: 0.488
# Epoch [2/50] Batch 900/1563                   Loss Discriminator: -0.956, loss Generator: 0.574
# Epoch [2/50] Batch 1000/1563                   Loss Discriminator: -0.954, loss Generator: 0.347
# Epoch [2/50] Batch 1100/1563                   Loss Discriminator: -1.037, loss Generator: 0.518
# Epoch [2/50] Batch 1200/1563                   Loss Discriminator: -0.890, loss Generator: 0.619
# Epoch [2/50] Batch 1300/1563                   Loss Discriminator: -0.933, loss Generator: 0.408
# Epoch [2/50] Batch 1400/1563                   Loss Discriminator: -0.952, loss Generator: 0.605
# Epoch [2/50] Batch 1500/1563                   Loss Discriminator: -0.878, loss Generator: 0.605
# Fretchet Distance:  303.2488663579923
# Epoch [3/50] Batch 0/1563                   Loss Discriminator: -0.874, loss Generator: 0.605
# Epoch [3/50] Batch 100/1563                   Loss Discriminator: -0.922, loss Generator: 0.515
# Epoch [3/50] Batch 200/1563                   Loss Discriminator: -0.739, loss Generator: 0.185
# Epoch [3/50] Batch 300/1563                   Loss Discriminator: -0.870, loss Generator: 0.363
# Epoch [3/50] Batch 400/1563                   Loss Discriminator: -0.873, loss Generator: 0.613
# Epoch [3/50] Batch 500/1563                   Loss Discriminator: -0.778, loss Generator: 0.555
# Epoch [3/50] Batch 600/1563                   Loss Discriminator: -0.862, loss Generator: 0.589
# Epoch [3/50] Batch 700/1563                   Loss Discriminator: -0.941, loss Generator: 0.422
# Epoch [3/50] Batch 800/1563                   Loss Discriminator: -0.819, loss Generator: 0.548
# Epoch [3/50] Batch 900/1563                   Loss Discriminator: -0.869, loss Generator: 0.497
# Epoch [3/50] Batch 1000/1563                   Loss Discriminator: -0.823, loss Generator: 0.577
# Epoch [3/50] Batch 1100/1563                   Loss Discriminator: -0.892, loss Generator: 0.554
# Epoch [3/50] Batch 1200/1563                   Loss Discriminator: -0.847, loss Generator: 0.587
# Epoch [3/50] Batch 1300/1563                   Loss Discriminator: -0.776, loss Generator: 0.606
# Epoch [3/50] Batch 1400/1563                   Loss Discriminator: -0.871, loss Generator: 0.580
# Epoch [3/50] Batch 1500/1563                   Loss Discriminator: -0.913, loss Generator: 0.346
# Fretchet Distance:  296.54090207511666
# Epoch [4/50] Batch 0/1563                   Loss Discriminator: -0.797, loss Generator: 0.248
# Epoch [4/50] Batch 100/1563                   Loss Discriminator: -0.790, loss Generator: 0.252
# Epoch [4/50] Batch 200/1563                   Loss Discriminator: -0.840, loss Generator: 0.557
# Epoch [4/50] Batch 300/1563                   Loss Discriminator: -0.790, loss Generator: 0.270
# Epoch [4/50] Batch 400/1563                   Loss Discriminator: -0.709, loss Generator: 0.580
# Epoch [4/50] Batch 500/1563                   Loss Discriminator: -0.656, loss Generator: 0.595
# Epoch [4/50] Batch 600/1563                   Loss Discriminator: -0.865, loss Generator: 0.565
# Epoch [4/50] Batch 700/1563                   Loss Discriminator: -0.737, loss Generator: 0.246
# Epoch [4/50] Batch 800/1563                   Loss Discriminator: -0.776, loss Generator: 0.621
# Epoch [4/50] Batch 900/1563                   Loss Discriminator: -0.893, loss Generator: 0.584
# Epoch [4/50] Batch 1000/1563                   Loss Discriminator: -0.690, loss Generator: 0.586
# Epoch [4/50] Batch 1100/1563                   Loss Discriminator: -0.702, loss Generator: 0.602
# Epoch [4/50] Batch 1200/1563                   Loss Discriminator: -0.768, loss Generator: 0.242
# Epoch [4/50] Batch 1300/1563                   Loss Discriminator: -0.706, loss Generator: 0.161
# Epoch [4/50] Batch 1400/1563                   Loss Discriminator: -0.737, loss Generator: 0.199
# Epoch [4/50] Batch 1500/1563                   Loss Discriminator: -0.776, loss Generator: 0.224
# Fretchet Distance:  317.91766736786064
# Epoch [5/50] Batch 0/1563                   Loss Discriminator: -0.834, loss Generator: 0.312
# Epoch [5/50] Batch 100/1563                   Loss Discriminator: -0.809, loss Generator: 0.609
# Epoch [5/50] Batch 200/1563                   Loss Discriminator: -0.655, loss Generator: 0.170
# Epoch [5/50] Batch 300/1563                   Loss Discriminator: -0.665, loss Generator: 0.575
# Epoch [5/50] Batch 400/1563                   Loss Discriminator: -0.705, loss Generator: 0.586
# Epoch [5/50] Batch 500/1563                   Loss Discriminator: -0.590, loss Generator: 0.117
# Epoch [5/50] Batch 600/1563                   Loss Discriminator: -0.704, loss Generator: 0.440
# Epoch [5/50] Batch 700/1563                   Loss Discriminator: -0.830, loss Generator: 0.595
# Epoch [5/50] Batch 800/1563                   Loss Discriminator: -0.690, loss Generator: 0.583
# Epoch [5/50] Batch 900/1563                   Loss Discriminator: -0.843, loss Generator: 0.580
# Epoch [5/50] Batch 1000/1563                   Loss Discriminator: -0.623, loss Generator: 0.591
# Epoch [5/50] Batch 1100/1563                   Loss Discriminator: -0.635, loss Generator: 0.587
# Epoch [5/50] Batch 1200/1563                   Loss Discriminator: -0.786, loss Generator: 0.199
# Epoch [5/50] Batch 1300/1563                   Loss Discriminator: -0.783, loss Generator: 0.587
# Epoch [5/50] Batch 1400/1563                   Loss Discriminator: -0.657, loss Generator: 0.249
# Epoch [5/50] Batch 1500/1563                   Loss Discriminator: -0.621, loss Generator: 0.559
# Fretchet Distance:  312.67053088961677
# Epoch [6/50] Batch 0/1563                   Loss Discriminator: -0.716, loss Generator: 0.249
# Epoch [6/50] Batch 100/1563                   Loss Discriminator: -0.681, loss Generator: 0.183
# Epoch [6/50] Batch 200/1563                   Loss Discriminator: -0.767, loss Generator: 0.310
# Epoch [6/50] Batch 300/1563                   Loss Discriminator: -0.720, loss Generator: 0.197
# Epoch [6/50] Batch 400/1563                   Loss Discriminator: -0.592, loss Generator: 0.089
# Epoch [6/50] Batch 500/1563                   Loss Discriminator: -0.694, loss Generator: 0.363
# Epoch [6/50] Batch 600/1563                   Loss Discriminator: -0.735, loss Generator: 0.567
# Epoch [6/50] Batch 700/1563                   Loss Discriminator: -0.834, loss Generator: 0.383
# Epoch [6/50] Batch 800/1563                   Loss Discriminator: -0.618, loss Generator: 0.146
# Epoch [6/50] Batch 900/1563                   Loss Discriminator: -0.757, loss Generator: 0.325
# Epoch [6/50] Batch 1000/1563                   Loss Discriminator: -0.684, loss Generator: 0.159
# Epoch [6/50] Batch 1100/1563                   Loss Discriminator: -0.684, loss Generator: 0.574
# Epoch [6/50] Batch 1200/1563                   Loss Discriminator: -0.633, loss Generator: 0.021
# Epoch [6/50] Batch 1300/1563                   Loss Discriminator: -0.556, loss Generator: 0.578
# Epoch [6/50] Batch 1400/1563                   Loss Discriminator: -0.643, loss Generator: 0.203
# Epoch [6/50] Batch 1500/1563                   Loss Discriminator: -0.561, loss Generator: 0.525
# Fretchet Distance:  286.2510610592965
# Epoch [7/50] Batch 0/1563                   Loss Discriminator: -0.815, loss Generator: 0.509
# Epoch [7/50] Batch 100/1563                   Loss Discriminator: -0.715, loss Generator: 0.153
# Epoch [7/50] Batch 200/1563                   Loss Discriminator: -0.677, loss Generator: 0.152
# Epoch [7/50] Batch 300/1563                   Loss Discriminator: -0.623, loss Generator: 0.159
# Epoch [7/50] Batch 400/1563                   Loss Discriminator: -0.609, loss Generator: 0.550
# Epoch [7/50] Batch 500/1563                   Loss Discriminator: -0.534, loss Generator: 0.542
# Epoch [7/50] Batch 600/1563                   Loss Discriminator: -0.743, loss Generator: 0.566
# Epoch [7/50] Batch 700/1563                   Loss Discriminator: -0.618, loss Generator: 0.586
# Epoch [7/50] Batch 800/1563                   Loss Discriminator: -0.703, loss Generator: 0.155
# Epoch [7/50] Batch 900/1563                   Loss Discriminator: -0.758, loss Generator: 0.460
# Epoch [7/50] Batch 1000/1563                   Loss Discriminator: -0.639, loss Generator: 0.092
# Epoch [7/50] Batch 1100/1563                   Loss Discriminator: -0.686, loss Generator: 0.560
# Epoch [7/50] Batch 1200/1563                   Loss Discriminator: -0.576, loss Generator: 0.578
# Epoch [7/50] Batch 1300/1563                   Loss Discriminator: -0.673, loss Generator: 0.044
# Epoch [7/50] Batch 1400/1563                   Loss Discriminator: -0.726, loss Generator: 0.288
# Epoch [7/50] Batch 1500/1563                   Loss Discriminator: -0.616, loss Generator: 0.219
# Fretchet Distance:  270.73242614552476
# Epoch [8/50] Batch 0/1563                   Loss Discriminator: -0.764, loss Generator: 0.559
# Epoch [8/50] Batch 100/1563                   Loss Discriminator: -0.652, loss Generator: 0.207
# Epoch [8/50] Batch 200/1563                   Loss Discriminator: -0.692, loss Generator: 0.056
# Epoch [8/50] Batch 300/1563                   Loss Discriminator: -0.599, loss Generator: 0.033
# Epoch [8/50] Batch 400/1563                   Loss Discriminator: -0.681, loss Generator: 0.165
# Epoch [8/50] Batch 500/1563                   Loss Discriminator: -0.547, loss Generator: 0.191
# Epoch [8/50] Batch 600/1563                   Loss Discriminator: -0.510, loss Generator: 0.501
# Epoch [8/50] Batch 700/1563                   Loss Discriminator: -0.697, loss Generator: 0.514
# Epoch [8/50] Batch 800/1563                   Loss Discriminator: -0.529, loss Generator: 0.068
# Epoch [8/50] Batch 900/1563                   Loss Discriminator: -0.632, loss Generator: 0.187
# Epoch [8/50] Batch 1000/1563                   Loss Discriminator: -0.564, loss Generator: 0.129
# Epoch [8/50] Batch 1100/1563                   Loss Discriminator: -0.645, loss Generator: 0.113
# Epoch [8/50] Batch 1200/1563                   Loss Discriminator: -0.637, loss Generator: 0.542
# Epoch [8/50] Batch 1300/1563                   Loss Discriminator: -0.706, loss Generator: 0.113
# Epoch [8/50] Batch 1400/1563                   Loss Discriminator: -0.622, loss Generator: 0.575
# Epoch [8/50] Batch 1500/1563                   Loss Discriminator: -0.655, loss Generator: 0.122
# Fretchet Distance:  282.2705944694439
# Epoch [9/50] Batch 0/1563                   Loss Discriminator: -0.662, loss Generator: 0.300
# Epoch [9/50] Batch 100/1563                   Loss Discriminator: -0.652, loss Generator: 0.518
# Epoch [9/50] Batch 200/1563                   Loss Discriminator: -0.603, loss Generator: 0.112
# Epoch [9/50] Batch 300/1563                   Loss Discriminator: -0.580, loss Generator: 0.509
# Epoch [9/50] Batch 400/1563                   Loss Discriminator: -0.509, loss Generator: 0.564
# Epoch [9/50] Batch 500/1563                   Loss Discriminator: -0.616, loss Generator: 0.451
# Epoch [9/50] Batch 600/1563                   Loss Discriminator: -0.557, loss Generator: 0.577
# Epoch [9/50] Batch 700/1563                   Loss Discriminator: -0.593, loss Generator: 0.575
# Epoch [9/50] Batch 800/1563                   Loss Discriminator: -0.591, loss Generator: 0.557
# Epoch [9/50] Batch 900/1563                   Loss Discriminator: -0.612, loss Generator: 0.076
# Epoch [9/50] Batch 1000/1563                   Loss Discriminator: -0.632, loss Generator: 0.249
# Epoch [9/50] Batch 1100/1563                   Loss Discriminator: -0.463, loss Generator: 0.517
# Epoch [9/50] Batch 1200/1563                   Loss Discriminator: -0.754, loss Generator: 0.572
# Epoch [9/50] Batch 1300/1563                   Loss Discriminator: -0.648, loss Generator: 0.430
# Epoch [9/50] Batch 1400/1563                   Loss Discriminator: -0.607, loss Generator: 0.160
# Epoch [9/50] Batch 1500/1563                   Loss Discriminator: -0.533, loss Generator: 0.526
# Fretchet Distance:  299.14405485062395
# Epoch [10/50] Batch 0/1563                   Loss Discriminator: -0.677, loss Generator: 0.524
# Epoch [10/50] Batch 100/1563                   Loss Discriminator: -0.544, loss Generator: 0.562
# Epoch [10/50] Batch 200/1563                   Loss Discriminator: -0.590, loss Generator: 0.534
# Epoch [10/50] Batch 300/1563                   Loss Discriminator: -0.596, loss Generator: -0.001
# Epoch [10/50] Batch 400/1563                   Loss Discriminator: -0.453, loss Generator: 0.543
# Epoch [10/50] Batch 500/1563                   Loss Discriminator: -0.480, loss Generator: 0.535
# Epoch [10/50] Batch 600/1563                   Loss Discriminator: -0.569, loss Generator: 0.466
# Epoch [10/50] Batch 700/1563                   Loss Discriminator: -0.539, loss Generator: 0.565
# Epoch [10/50] Batch 800/1563                   Loss Discriminator: -0.520, loss Generator: 0.220
# Epoch [10/50] Batch 900/1563                   Loss Discriminator: -0.572, loss Generator: 0.586
# Epoch [10/50] Batch 1000/1563                   Loss Discriminator: -0.526, loss Generator: 0.526
# Epoch [10/50] Batch 1100/1563                   Loss Discriminator: -0.575, loss Generator: 0.165
# Epoch [10/50] Batch 1200/1563                   Loss Discriminator: -0.545, loss Generator: 0.554
# Epoch [10/50] Batch 1300/1563                   Loss Discriminator: -0.523, loss Generator: -0.065
# Epoch [10/50] Batch 1400/1563                   Loss Discriminator: -0.627, loss Generator: 0.385
# Epoch [10/50] Batch 1500/1563                   Loss Discriminator: -0.527, loss Generator: 0.573
# Fretchet Distance:  276.06686919613446
# Epoch [11/50] Batch 0/1563                   Loss Discriminator: -0.605, loss Generator: 0.265
# Epoch [11/50] Batch 100/1563                   Loss Discriminator: -0.510, loss Generator: -0.049
# Epoch [11/50] Batch 200/1563                   Loss Discriminator: -0.500, loss Generator: 0.506
# Epoch [11/50] Batch 300/1563                   Loss Discriminator: -0.512, loss Generator: 0.368
# Epoch [11/50] Batch 400/1563                   Loss Discriminator: -0.715, loss Generator: 0.353
# Epoch [11/50] Batch 500/1563                   Loss Discriminator: -0.637, loss Generator: 0.512
# Epoch [11/50] Batch 600/1563                   Loss Discriminator: -0.540, loss Generator: -0.034
# Epoch [11/50] Batch 700/1563                   Loss Discriminator: -0.442, loss Generator: 0.141
# Epoch [11/50] Batch 800/1563                   Loss Discriminator: -0.573, loss Generator: 0.032
# Epoch [11/50] Batch 900/1563                   Loss Discriminator: -0.595, loss Generator: -0.020
# Epoch [11/50] Batch 1000/1563                   Loss Discriminator: -0.555, loss Generator: 0.564
# Epoch [11/50] Batch 1100/1563                   Loss Discriminator: -0.497, loss Generator: 0.034
# Epoch [11/50] Batch 1200/1563                   Loss Discriminator: -0.458, loss Generator: 0.053
# Epoch [11/50] Batch 1300/1563                   Loss Discriminator: -0.447, loss Generator: 0.085
# Epoch [11/50] Batch 1400/1563                   Loss Discriminator: -0.525, loss Generator: 0.079
# Epoch [11/50] Batch 1500/1563                   Loss Discriminator: -0.565, loss Generator: 0.562
# Fretchet Distance:  281.81212593274824
# Epoch [12/50] Batch 0/1563                   Loss Discriminator: -0.567, loss Generator: 0.281
# Epoch [12/50] Batch 100/1563                   Loss Discriminator: -0.472, loss Generator: 0.552
# Epoch [12/50] Batch 200/1563                   Loss Discriminator: -0.499, loss Generator: 0.100
# Epoch [12/50] Batch 300/1563                   Loss Discriminator: -0.543, loss Generator: 0.545
# Epoch [12/50] Batch 400/1563                   Loss Discriminator: -0.670, loss Generator: 0.485
# Epoch [12/50] Batch 500/1563                   Loss Discriminator: -0.604, loss Generator: -0.023
# Epoch [12/50] Batch 600/1563                   Loss Discriminator: -0.442, loss Generator: 0.520
# Epoch [12/50] Batch 700/1563                   Loss Discriminator: -0.730, loss Generator: 0.521
# Epoch [12/50] Batch 800/1563                   Loss Discriminator: -0.608, loss Generator: 0.263
# Epoch [12/50] Batch 900/1563                   Loss Discriminator: -0.557, loss Generator: 0.504
# Epoch [12/50] Batch 1000/1563                   Loss Discriminator: -0.505, loss Generator: 0.581
# Epoch [12/50] Batch 1100/1563                   Loss Discriminator: -0.540, loss Generator: 0.114
# Epoch [12/50] Batch 1200/1563                   Loss Discriminator: -0.518, loss Generator: 0.564
# Epoch [12/50] Batch 1300/1563                   Loss Discriminator: -0.487, loss Generator: 0.364
# Epoch [12/50] Batch 1400/1563                   Loss Discriminator: -0.594, loss Generator: 0.145
# Epoch [12/50] Batch 1500/1563                   Loss Discriminator: -0.605, loss Generator: 0.547
# Fretchet Distance:  268.80224763855875
# Epoch [13/50] Batch 0/1563                   Loss Discriminator: -0.404, loss Generator: 0.486
# Epoch [13/50] Batch 100/1563                   Loss Discriminator: -0.573, loss Generator: 0.557
# Epoch [13/50] Batch 200/1563                   Loss Discriminator: -0.632, loss Generator: 0.486
# Epoch [13/50] Batch 300/1563                   Loss Discriminator: -0.582, loss Generator: 0.372
# Epoch [13/50] Batch 400/1563                   Loss Discriminator: -0.530, loss Generator: -0.081
# Epoch [13/50] Batch 500/1563                   Loss Discriminator: -0.675, loss Generator: 0.197
# Epoch [13/50] Batch 600/1563                   Loss Discriminator: -0.659, loss Generator: 0.133
# Epoch [13/50] Batch 700/1563                   Loss Discriminator: -0.446, loss Generator: 0.409
# Epoch [13/50] Batch 800/1563                   Loss Discriminator: -0.540, loss Generator: 0.082
# Epoch [13/50] Batch 900/1563                   Loss Discriminator: -0.607, loss Generator: 0.201
# Epoch [13/50] Batch 1000/1563                   Loss Discriminator: -0.550, loss Generator: 0.090
# Epoch [13/50] Batch 1100/1563                   Loss Discriminator: -0.476, loss Generator: 0.446
# Epoch [13/50] Batch 1200/1563                   Loss Discriminator: -0.562, loss Generator: 0.477
# Epoch [13/50] Batch 1300/1563                   Loss Discriminator: -0.552, loss Generator: 0.547
# Epoch [13/50] Batch 1400/1563                   Loss Discriminator: -0.461, loss Generator: 0.502
# Epoch [13/50] Batch 1500/1563                   Loss Discriminator: -0.546, loss Generator: 0.013
# Fretchet Distance:  318.64422441155745
# Epoch [14/50] Batch 0/1563                   Loss Discriminator: -0.498, loss Generator: 0.002
# Epoch [14/50] Batch 100/1563                   Loss Discriminator: -0.384, loss Generator: 0.471
# Epoch [14/50] Batch 200/1563                   Loss Discriminator: -0.513, loss Generator: 0.535
# Epoch [14/50] Batch 300/1563                   Loss Discriminator: -0.491, loss Generator: -0.030
# Epoch [14/50] Batch 400/1563                   Loss Discriminator: -0.364, loss Generator: 0.474
# Epoch [14/50] Batch 500/1563                   Loss Discriminator: -0.584, loss Generator: 0.469
# Epoch [14/50] Batch 600/1563                   Loss Discriminator: -0.469, loss Generator: -0.051
# Epoch [14/50] Batch 700/1563                   Loss Discriminator: -0.422, loss Generator: 0.525
# Epoch [14/50] Batch 800/1563                   Loss Discriminator: -0.537, loss Generator: 0.558
# Epoch [14/50] Batch 900/1563                   Loss Discriminator: -0.537, loss Generator: 0.508
# Epoch [14/50] Batch 1000/1563                   Loss Discriminator: -0.564, loss Generator: 0.520
# Epoch [14/50] Batch 1100/1563                   Loss Discriminator: -0.466, loss Generator: 0.570
# Epoch [14/50] Batch 1200/1563                   Loss Discriminator: -0.522, loss Generator: 0.030
# Epoch [14/50] Batch 1300/1563                   Loss Discriminator: -0.549, loss Generator: 0.168
# Epoch [14/50] Batch 1400/1563                   Loss Discriminator: -0.471, loss Generator: 0.479
# Epoch [14/50] Batch 1500/1563                   Loss Discriminator: -0.542, loss Generator: 0.483
# Fretchet Distance:  264.2662889828428
# Epoch [15/50] Batch 0/1563                   Loss Discriminator: -0.574, loss Generator: 0.430
# Epoch [15/50] Batch 100/1563                   Loss Discriminator: -0.558, loss Generator: 0.060
# Epoch [15/50] Batch 200/1563                   Loss Discriminator: -0.570, loss Generator: 0.258
# Epoch [15/50] Batch 300/1563                   Loss Discriminator: -0.566, loss Generator: 0.427
# Epoch [15/50] Batch 400/1563                   Loss Discriminator: -0.517, loss Generator: 0.510
# Epoch [15/50] Batch 500/1563                   Loss Discriminator: -0.637, loss Generator: 0.302
# Epoch [15/50] Batch 600/1563                   Loss Discriminator: -0.473, loss Generator: 0.472
# Epoch [15/50] Batch 700/1563                   Loss Discriminator: -0.610, loss Generator: 0.501
# Epoch [15/50] Batch 800/1563                   Loss Discriminator: -0.566, loss Generator: 0.230
# Epoch [15/50] Batch 900/1563                   Loss Discriminator: -0.461, loss Generator: 0.148
# Epoch [15/50] Batch 1000/1563                   Loss Discriminator: -0.620, loss Generator: 0.055
# Epoch [15/50] Batch 1100/1563                   Loss Discriminator: -0.522, loss Generator: 0.508
# Epoch [15/50] Batch 1200/1563                   Loss Discriminator: -0.548, loss Generator: -0.049
# Epoch [15/50] Batch 1300/1563                   Loss Discriminator: -0.623, loss Generator: 0.566
# Epoch [15/50] Batch 1400/1563                   Loss Discriminator: -0.580, loss Generator: 0.328
# Epoch [15/50] Batch 1500/1563                   Loss Discriminator: -0.509, loss Generator: 0.578
# Fretchet Distance:  288.12380281355735
# Epoch [16/50] Batch 0/1563                   Loss Discriminator: -0.561, loss Generator: 0.395
# Epoch [16/50] Batch 100/1563                   Loss Discriminator: -0.527, loss Generator: 0.088
# Epoch [16/50] Batch 200/1563                   Loss Discriminator: -0.474, loss Generator: 0.272
# Epoch [16/50] Batch 300/1563                   Loss Discriminator: -0.437, loss Generator: 0.514
# Epoch [16/50] Batch 400/1563                   Loss Discriminator: -0.515, loss Generator: 0.527
# Epoch [16/50] Batch 500/1563                   Loss Discriminator: -0.551, loss Generator: 0.560
# Epoch [16/50] Batch 600/1563                   Loss Discriminator: -0.348, loss Generator: 0.426
# Epoch [16/50] Batch 700/1563                   Loss Discriminator: -0.528, loss Generator: 0.536
# Epoch [16/50] Batch 800/1563                   Loss Discriminator: -0.545, loss Generator: 0.553
# Epoch [16/50] Batch 900/1563                   Loss Discriminator: -0.452, loss Generator: -0.056
# Epoch [16/50] Batch 1000/1563                   Loss Discriminator: -0.458, loss Generator: 0.464
# Epoch [16/50] Batch 1100/1563                   Loss Discriminator: -0.455, loss Generator: 0.524
# Epoch [16/50] Batch 1200/1563                   Loss Discriminator: -0.464, loss Generator: -0.011
# Epoch [16/50] Batch 1300/1563                   Loss Discriminator: -0.449, loss Generator: 0.523
# Epoch [16/50] Batch 1400/1563                   Loss Discriminator: -0.542, loss Generator: -0.064
# Epoch [16/50] Batch 1500/1563                   Loss Discriminator: -0.457, loss Generator: -0.078
# Fretchet Distance:  284.8037006354326
# Epoch [17/50] Batch 0/1563                   Loss Discriminator: -0.513, loss Generator: 0.393
# Epoch [17/50] Batch 100/1563                   Loss Discriminator: -0.389, loss Generator: 0.002
# Epoch [17/50] Batch 200/1563                   Loss Discriminator: -0.539, loss Generator: 0.087
# Epoch [17/50] Batch 300/1563                   Loss Discriminator: -0.551, loss Generator: 0.181
# Epoch [17/50] Batch 400/1563                   Loss Discriminator: -0.399, loss Generator: 0.159
# Epoch [17/50] Batch 500/1563                   Loss Discriminator: -0.513, loss Generator: 0.418
# Epoch [17/50] Batch 600/1563                   Loss Discriminator: -0.529, loss Generator: 0.333
# Epoch [17/50] Batch 700/1563                   Loss Discriminator: -0.404, loss Generator: 0.055
# Epoch [17/50] Batch 800/1563                   Loss Discriminator: -0.432, loss Generator: 0.465
# Epoch [17/50] Batch 900/1563                   Loss Discriminator: -0.544, loss Generator: 0.131
# Epoch [17/50] Batch 1000/1563                   Loss Discriminator: -0.631, loss Generator: 0.007
# Epoch [17/50] Batch 1100/1563                   Loss Discriminator: -0.382, loss Generator: -0.017
# Epoch [17/50] Batch 1200/1563                   Loss Discriminator: -0.498, loss Generator: 0.249
# Epoch [17/50] Batch 1300/1563                   Loss Discriminator: -0.339, loss Generator: 0.405
# Epoch [17/50] Batch 1400/1563                   Loss Discriminator: -0.447, loss Generator: -0.017
# Epoch [17/50] Batch 1500/1563                   Loss Discriminator: -0.527, loss Generator: 0.286
# Fretchet Distance:  311.50624445712384
# Epoch [18/50] Batch 0/1563                   Loss Discriminator: -0.473, loss Generator: -0.124
# Epoch [18/50] Batch 100/1563                   Loss Discriminator: -0.537, loss Generator: 0.399
# Epoch [18/50] Batch 200/1563                   Loss Discriminator: -0.482, loss Generator: 0.463
# Epoch [18/50] Batch 300/1563                   Loss Discriminator: -0.392, loss Generator: -0.111
# Epoch [18/50] Batch 400/1563                   Loss Discriminator: -0.508, loss Generator: -0.023
# Epoch [18/50] Batch 500/1563                   Loss Discriminator: -0.540, loss Generator: 0.475
# Epoch [18/50] Batch 600/1563                   Loss Discriminator: -0.448, loss Generator: 0.562
# Epoch [18/50] Batch 700/1563                   Loss Discriminator: -0.607, loss Generator: 0.364
# Epoch [18/50] Batch 800/1563                   Loss Discriminator: -0.566, loss Generator: 0.268
# Epoch [18/50] Batch 900/1563                   Loss Discriminator: -0.400, loss Generator: 0.016
# Epoch [18/50] Batch 1000/1563                   Loss Discriminator: -0.373, loss Generator: -0.130
# Epoch [18/50] Batch 1100/1563                   Loss Discriminator: -0.577, loss Generator: 0.500
# Epoch [18/50] Batch 1200/1563                   Loss Discriminator: -0.502, loss Generator: 0.548
# Epoch [18/50] Batch 1300/1563                   Loss Discriminator: -0.575, loss Generator: 0.370
# Epoch [18/50] Batch 1400/1563                   Loss Discriminator: -0.450, loss Generator: 0.569
# Epoch [18/50] Batch 1500/1563                   Loss Discriminator: -0.521, loss Generator: 0.491
# Fretchet Distance:  265.1154134993921
# Epoch [19/50] Batch 0/1563                   Loss Discriminator: -0.498, loss Generator: 0.006
# Epoch [19/50] Batch 100/1563                   Loss Discriminator: -0.533, loss Generator: 0.032
# Epoch [19/50] Batch 200/1563                   Loss Discriminator: -0.523, loss Generator: 0.324
# Epoch [19/50] Batch 300/1563                   Loss Discriminator: -0.311, loss Generator: 0.428
# Epoch [19/50] Batch 400/1563                   Loss Discriminator: -0.547, loss Generator: 0.063
# Epoch [19/50] Batch 500/1563                   Loss Discriminator: -0.467, loss Generator: 0.564
# Epoch [19/50] Batch 600/1563                   Loss Discriminator: -0.534, loss Generator: 0.426
# Epoch [19/50] Batch 700/1563                   Loss Discriminator: -0.370, loss Generator: 0.513
# Epoch [19/50] Batch 800/1563                   Loss Discriminator: -0.395, loss Generator: -0.030
# Epoch [19/50] Batch 900/1563                   Loss Discriminator: -0.435, loss Generator: 0.044
# Epoch [19/50] Batch 1000/1563                   Loss Discriminator: -0.495, loss Generator: 0.383
# Epoch [19/50] Batch 1100/1563                   Loss Discriminator: -0.453, loss Generator: -0.192
# Epoch [19/50] Batch 1200/1563                   Loss Discriminator: -0.468, loss Generator: 0.179
# Epoch [19/50] Batch 1300/1563                   Loss Discriminator: -0.486, loss Generator: -0.165
# Epoch [19/50] Batch 1400/1563                   Loss Discriminator: -0.549, loss Generator: 0.182
# Epoch [19/50] Batch 1500/1563                   Loss Discriminator: -0.542, loss Generator: -0.238
# Fretchet Distance:  310.0188218670113
# Epoch [20/50] Batch 0/1563                   Loss Discriminator: -0.443, loss Generator: 0.285
# Epoch [20/50] Batch 100/1563                   Loss Discriminator: -0.545, loss Generator: 0.440
# Epoch [20/50] Batch 200/1563                   Loss Discriminator: -0.527, loss Generator: 0.145
# Epoch [20/50] Batch 300/1563                   Loss Discriminator: -0.437, loss Generator: -0.095
# Epoch [20/50] Batch 400/1563                   Loss Discriminator: -0.485, loss Generator: 0.555
# Epoch [20/50] Batch 500/1563                   Loss Discriminator: -0.561, loss Generator: 0.299
# Epoch [20/50] Batch 600/1563                   Loss Discriminator: -0.507, loss Generator: -0.235
# Epoch [20/50] Batch 700/1563                   Loss Discriminator: -0.527, loss Generator: 0.313
# Epoch [20/50] Batch 800/1563                   Loss Discriminator: -0.669, loss Generator: 0.474
# Epoch [20/50] Batch 900/1563                   Loss Discriminator: -0.485, loss Generator: 0.082
# Epoch [20/50] Batch 1000/1563                   Loss Discriminator: -0.557, loss Generator: 0.406
# Epoch [20/50] Batch 1100/1563                   Loss Discriminator: -0.557, loss Generator: 0.072
# Epoch [20/50] Batch 1200/1563                   Loss Discriminator: -0.522, loss Generator: 0.468
# Epoch [20/50] Batch 1300/1563                   Loss Discriminator: -0.331, loss Generator: 0.324
# Epoch [20/50] Batch 1400/1563                   Loss Discriminator: -0.555, loss Generator: -0.017
# Epoch [20/50] Batch 1500/1563                   Loss Discriminator: -0.385, loss Generator: 0.312
# Fretchet Distance:  266.67452552306645
# Epoch [21/50] Batch 0/1563                   Loss Discriminator: -0.438, loss Generator: 0.456
# Epoch [21/50] Batch 100/1563                   Loss Discriminator: -0.468, loss Generator: 0.127
# Epoch [21/50] Batch 200/1563                   Loss Discriminator: -0.428, loss Generator: 0.541
# Epoch [21/50] Batch 300/1563                   Loss Discriminator: -0.457, loss Generator: 0.505
# Epoch [21/50] Batch 400/1563                   Loss Discriminator: -0.412, loss Generator: 0.512
# Epoch [21/50] Batch 500/1563                   Loss Discriminator: -0.542, loss Generator: 0.342
# Epoch [21/50] Batch 600/1563                   Loss Discriminator: -0.295, loss Generator: 0.387
# Epoch [21/50] Batch 700/1563                   Loss Discriminator: -0.536, loss Generator: 0.591
# Epoch [21/50] Batch 800/1563                   Loss Discriminator: -0.454, loss Generator: 0.152
# Epoch [21/50] Batch 900/1563                   Loss Discriminator: -0.344, loss Generator: 0.485
# Epoch [21/50] Batch 1000/1563                   Loss Discriminator: -0.427, loss Generator: -0.091
# Epoch [21/50] Batch 1100/1563                   Loss Discriminator: -0.463, loss Generator: -0.070
# Epoch [21/50] Batch 1200/1563                   Loss Discriminator: -0.500, loss Generator: 0.251
# Epoch [21/50] Batch 1300/1563                   Loss Discriminator: -0.439, loss Generator: 0.285
# Epoch [21/50] Batch 1400/1563                   Loss Discriminator: -0.512, loss Generator: -0.006
# Epoch [21/50] Batch 1500/1563                   Loss Discriminator: -0.511, loss Generator: 0.584
# Fretchet Distance:  273.7872813850864
# Epoch [22/50] Batch 0/1563                   Loss Discriminator: -0.571, loss Generator: 0.529
# Epoch [22/50] Batch 100/1563                   Loss Discriminator: -0.525, loss Generator: 0.196
# Epoch [22/50] Batch 200/1563                   Loss Discriminator: -0.439, loss Generator: 0.342
# Epoch [22/50] Batch 300/1563                   Loss Discriminator: -0.469, loss Generator: 0.059
# Epoch [22/50] Batch 400/1563                   Loss Discriminator: -0.465, loss Generator: -0.096
# Epoch [22/50] Batch 500/1563                   Loss Discriminator: -0.526, loss Generator: 0.079
# Epoch [22/50] Batch 600/1563                   Loss Discriminator: -0.465, loss Generator: 0.466
# Epoch [22/50] Batch 700/1563                   Loss Discriminator: -0.556, loss Generator: 0.464
# Epoch [22/50] Batch 800/1563                   Loss Discriminator: -0.365, loss Generator: -0.107
# Epoch [22/50] Batch 900/1563                   Loss Discriminator: -0.454, loss Generator: 0.429
# Epoch [22/50] Batch 1000/1563                   Loss Discriminator: -0.524, loss Generator: -0.035
# Epoch [22/50] Batch 1100/1563                   Loss Discriminator: -0.472, loss Generator: 0.530
# Epoch [22/50] Batch 1200/1563                   Loss Discriminator: -0.432, loss Generator: 0.531
# Epoch [22/50] Batch 1300/1563                   Loss Discriminator: -0.481, loss Generator: 0.527
# Epoch [22/50] Batch 1400/1563                   Loss Discriminator: -0.428, loss Generator: 0.122
# Epoch [22/50] Batch 1500/1563                   Loss Discriminator: -0.516, loss Generator: -0.001
# Fretchet Distance:  292.8370088356401
# Epoch [23/50] Batch 0/1563                   Loss Discriminator: -0.499, loss Generator: 0.422
# Epoch [23/50] Batch 100/1563                   Loss Discriminator: -0.537, loss Generator: 0.463
# Epoch [23/50] Batch 200/1563                   Loss Discriminator: -0.453, loss Generator: 0.432
# Epoch [23/50] Batch 300/1563                   Loss Discriminator: -0.441, loss Generator: 0.035
# Epoch [23/50] Batch 400/1563                   Loss Discriminator: -0.410, loss Generator: 0.355
# Epoch [23/50] Batch 500/1563                   Loss Discriminator: -0.576, loss Generator: 0.373
# Epoch [23/50] Batch 600/1563                   Loss Discriminator: -0.424, loss Generator: -0.207
# Epoch [23/50] Batch 700/1563                   Loss Discriminator: -0.398, loss Generator: 0.163
# Epoch [23/50] Batch 800/1563                   Loss Discriminator: -0.500, loss Generator: 0.167
# Epoch [23/50] Batch 900/1563                   Loss Discriminator: -0.415, loss Generator: 0.065
# Epoch [23/50] Batch 1000/1563                   Loss Discriminator: -0.447, loss Generator: 0.492
# Epoch [23/50] Batch 1100/1563                   Loss Discriminator: -0.546, loss Generator: 0.373
# Epoch [23/50] Batch 1200/1563                   Loss Discriminator: -0.533, loss Generator: 0.465
# Epoch [23/50] Batch 1300/1563                   Loss Discriminator: -0.442, loss Generator: -0.200
# Epoch [23/50] Batch 1400/1563                   Loss Discriminator: -0.361, loss Generator: -0.049
# Epoch [23/50] Batch 1500/1563                   Loss Discriminator: -0.429, loss Generator: 0.475
# Fretchet Distance:  259.6230764478637
# Epoch [24/50] Batch 0/1563                   Loss Discriminator: -0.542, loss Generator: 0.452
# Epoch [24/50] Batch 100/1563                   Loss Discriminator: -0.425, loss Generator: -0.053
# Epoch [24/50] Batch 200/1563                   Loss Discriminator: -0.526, loss Generator: 0.447
# Epoch [24/50] Batch 300/1563                   Loss Discriminator: -0.318, loss Generator: 0.408
# Epoch [24/50] Batch 400/1563                   Loss Discriminator: -0.523, loss Generator: 0.120
# Epoch [24/50] Batch 500/1563                   Loss Discriminator: -0.371, loss Generator: -0.040
# Epoch [24/50] Batch 600/1563                   Loss Discriminator: -0.446, loss Generator: 0.289
# Epoch [24/50] Batch 700/1563                   Loss Discriminator: -0.415, loss Generator: -0.032
# Epoch [24/50] Batch 800/1563                   Loss Discriminator: -0.542, loss Generator: 0.284
# Epoch [24/50] Batch 900/1563                   Loss Discriminator: -0.503, loss Generator: 0.385
# Epoch [24/50] Batch 1000/1563                   Loss Discriminator: -0.519, loss Generator: 0.508
# Epoch [24/50] Batch 1100/1563                   Loss Discriminator: -0.535, loss Generator: 0.210
# Epoch [24/50] Batch 1200/1563                   Loss Discriminator: -0.465, loss Generator: 0.511
# Epoch [24/50] Batch 1300/1563                   Loss Discriminator: -0.410, loss Generator: -0.156
# Epoch [24/50] Batch 1400/1563                   Loss Discriminator: -0.473, loss Generator: 0.513
# Epoch [24/50] Batch 1500/1563                   Loss Discriminator: -0.600, loss Generator: 0.322
# Fretchet Distance:  320.4158774284829
# Epoch [25/50] Batch 0/1563                   Loss Discriminator: -0.445, loss Generator: 0.246
# Epoch [25/50] Batch 100/1563                   Loss Discriminator: -0.370, loss Generator: 0.091
# Epoch [25/50] Batch 200/1563                   Loss Discriminator: -0.406, loss Generator: 0.043
# Epoch [25/50] Batch 300/1563                   Loss Discriminator: -0.470, loss Generator: 0.412
# Epoch [25/50] Batch 400/1563                   Loss Discriminator: -0.453, loss Generator: -0.102
# Epoch [25/50] Batch 500/1563                   Loss Discriminator: -0.437, loss Generator: 0.383
# Epoch [25/50] Batch 600/1563                   Loss Discriminator: -0.351, loss Generator: 0.508
# Epoch [25/50] Batch 700/1563                   Loss Discriminator: -0.492, loss Generator: 0.466
# Epoch [25/50] Batch 800/1563                   Loss Discriminator: -0.431, loss Generator: 0.535
# Epoch [25/50] Batch 900/1563                   Loss Discriminator: -0.432, loss Generator: 0.560
# Epoch [25/50] Batch 1000/1563                   Loss Discriminator: -0.479, loss Generator: 0.445
# Epoch [25/50] Batch 1100/1563                   Loss Discriminator: -0.330, loss Generator: 0.507
# Epoch [25/50] Batch 1200/1563                   Loss Discriminator: -0.484, loss Generator: 0.331
# Epoch [25/50] Batch 1300/1563                   Loss Discriminator: -0.495, loss Generator: 0.151
# Epoch [25/50] Batch 1400/1563                   Loss Discriminator: -0.493, loss Generator: 0.169
# Epoch [25/50] Batch 1500/1563                   Loss Discriminator: -0.510, loss Generator: 0.450
# Fretchet Distance:  304.840831122129
# Epoch [26/50] Batch 0/1563                   Loss Discriminator: -0.337, loss Generator: -0.200
# Epoch [26/50] Batch 100/1563                   Loss Discriminator: -0.441, loss Generator: 0.467
# Epoch [26/50] Batch 200/1563                   Loss Discriminator: -0.399, loss Generator: 0.153
# Epoch [26/50] Batch 300/1563                   Loss Discriminator: -0.508, loss Generator: 0.392
# Epoch [26/50] Batch 400/1563                   Loss Discriminator: -0.470, loss Generator: -0.126
# Epoch [26/50] Batch 500/1563                   Loss Discriminator: -0.516, loss Generator: 0.108
# Epoch [26/50] Batch 600/1563                   Loss Discriminator: -0.490, loss Generator: 0.326
# Epoch [26/50] Batch 700/1563                   Loss Discriminator: -0.391, loss Generator: 0.303
# Epoch [26/50] Batch 800/1563                   Loss Discriminator: -0.521, loss Generator: 0.367
# Epoch [26/50] Batch 900/1563                   Loss Discriminator: -0.505, loss Generator: 0.530
# Epoch [26/50] Batch 1000/1563                   Loss Discriminator: -0.412, loss Generator: 0.465
# Epoch [26/50] Batch 1100/1563                   Loss Discriminator: -0.449, loss Generator: 0.402
# Epoch [26/50] Batch 1200/1563                   Loss Discriminator: -0.422, loss Generator: 0.469
# Epoch [26/50] Batch 1300/1563                   Loss Discriminator: -0.409, loss Generator: 0.451
# Epoch [26/50] Batch 1400/1563                   Loss Discriminator: -0.440, loss Generator: -0.115
# Epoch [26/50] Batch 1500/1563                   Loss Discriminator: -0.531, loss Generator: 0.317
# Fretchet Distance:  281.01416147641623
# Epoch [27/50] Batch 0/1563                   Loss Discriminator: -0.494, loss Generator: 0.167
# Epoch [27/50] Batch 100/1563                   Loss Discriminator: -0.508, loss Generator: 0.409
# Epoch [27/50] Batch 200/1563                   Loss Discriminator: -0.538, loss Generator: 0.467
# Epoch [27/50] Batch 300/1563                   Loss Discriminator: -0.354, loss Generator: 0.418
# Epoch [27/50] Batch 400/1563                   Loss Discriminator: -0.438, loss Generator: 0.130
# Epoch [27/50] Batch 500/1563                   Loss Discriminator: -0.357, loss Generator: -0.015
# Epoch [27/50] Batch 600/1563                   Loss Discriminator: -0.534, loss Generator: 0.136
# Epoch [27/50] Batch 700/1563                   Loss Discriminator: -0.466, loss Generator: 0.232
# Epoch [27/50] Batch 800/1563                   Loss Discriminator: -0.590, loss Generator: 0.525
# Epoch [27/50] Batch 900/1563                   Loss Discriminator: -0.407, loss Generator: 0.178
# Epoch [27/50] Batch 1000/1563                   Loss Discriminator: -0.541, loss Generator: 0.460
# Epoch [27/50] Batch 1100/1563                   Loss Discriminator: -0.489, loss Generator: 0.167
# Epoch [27/50] Batch 1200/1563                   Loss Discriminator: -0.384, loss Generator: 0.332
# Epoch [27/50] Batch 1300/1563                   Loss Discriminator: -0.494, loss Generator: 0.460
# Epoch [27/50] Batch 1400/1563                   Loss Discriminator: -0.322, loss Generator: 0.525
# Epoch [27/50] Batch 1500/1563                   Loss Discriminator: -0.441, loss Generator: 0.570
# Fretchet Distance:  290.71983221433493
# Epoch [28/50] Batch 0/1563                   Loss Discriminator: -0.423, loss Generator: 0.318
# Epoch [28/50] Batch 100/1563                   Loss Discriminator: -0.423, loss Generator: 0.455
# Epoch [28/50] Batch 200/1563                   Loss Discriminator: -0.466, loss Generator: 0.152
# Epoch [28/50] Batch 300/1563                   Loss Discriminator: -0.513, loss Generator: 0.495
# Epoch [28/50] Batch 400/1563                   Loss Discriminator: -0.358, loss Generator: -0.023
# Epoch [28/50] Batch 500/1563                   Loss Discriminator: -0.429, loss Generator: 0.027
# Epoch [28/50] Batch 600/1563                   Loss Discriminator: -0.375, loss Generator: 0.156
# Epoch [28/50] Batch 700/1563                   Loss Discriminator: -0.385, loss Generator: 0.012
# Epoch [28/50] Batch 800/1563                   Loss Discriminator: -0.389, loss Generator: 0.534
# Epoch [28/50] Batch 900/1563                   Loss Discriminator: -0.438, loss Generator: -0.110
# Epoch [28/50] Batch 1000/1563                   Loss Discriminator: -0.366, loss Generator: -0.147
# Epoch [28/50] Batch 1100/1563                   Loss Discriminator: -0.381, loss Generator: 0.543
# Epoch [28/50] Batch 1200/1563                   Loss Discriminator: -0.466, loss Generator: 0.333
# Epoch [28/50] Batch 1300/1563                   Loss Discriminator: -0.488, loss Generator: -0.000
# Epoch [28/50] Batch 1400/1563                   Loss Discriminator: -0.445, loss Generator: 0.284
# Epoch [28/50] Batch 1500/1563                   Loss Discriminator: -0.518, loss Generator: 0.364
# Fretchet Distance:  285.24306540328797
# Epoch [29/50] Batch 0/1563                   Loss Discriminator: -0.476, loss Generator: 0.105
# Epoch [29/50] Batch 100/1563                   Loss Discriminator: -0.374, loss Generator: -0.132
# Epoch [29/50] Batch 200/1563                   Loss Discriminator: -0.469, loss Generator: 0.356
# Epoch [29/50] Batch 300/1563                   Loss Discriminator: -0.372, loss Generator: -0.111
# Epoch [29/50] Batch 400/1563                   Loss Discriminator: -0.341, loss Generator: -0.140
# Epoch [29/50] Batch 500/1563                   Loss Discriminator: -0.456, loss Generator: -0.029
# Epoch [29/50] Batch 600/1563                   Loss Discriminator: -0.376, loss Generator: 0.098
# Epoch [29/50] Batch 700/1563                   Loss Discriminator: -0.482, loss Generator: 0.057
# Epoch [29/50] Batch 800/1563                   Loss Discriminator: -0.555, loss Generator: 0.368
# Epoch [29/50] Batch 900/1563                   Loss Discriminator: -0.381, loss Generator: -0.020
# Epoch [29/50] Batch 1000/1563                   Loss Discriminator: -0.462, loss Generator: 0.427
# Epoch [29/50] Batch 1100/1563                   Loss Discriminator: -0.443, loss Generator: 0.058
# Epoch [29/50] Batch 1200/1563                   Loss Discriminator: -0.473, loss Generator: 0.472
# Epoch [29/50] Batch 1300/1563                   Loss Discriminator: -0.420, loss Generator: -0.003
# Epoch [29/50] Batch 1400/1563                   Loss Discriminator: -0.412, loss Generator: 0.447
# Epoch [29/50] Batch 1500/1563                   Loss Discriminator: -0.412, loss Generator: 0.191
# Fretchet Distance:  305.91730400446033
# Epoch [30/50] Batch 0/1563                   Loss Discriminator: -0.389, loss Generator: 0.558
# Epoch [30/50] Batch 100/1563                   Loss Discriminator: -0.365, loss Generator: -0.152
# Epoch [30/50] Batch 200/1563                   Loss Discriminator: -0.437, loss Generator: 0.320
# Epoch [30/50] Batch 300/1563                   Loss Discriminator: -0.501, loss Generator: 0.448
# Epoch [30/50] Batch 400/1563                   Loss Discriminator: -0.347, loss Generator: 0.456
# Epoch [30/50] Batch 500/1563                   Loss Discriminator: -0.488, loss Generator: 0.377
# Epoch [30/50] Batch 600/1563                   Loss Discriminator: -0.467, loss Generator: 0.449
# Epoch [30/50] Batch 700/1563                   Loss Discriminator: -0.354, loss Generator: -0.125
# Epoch [30/50] Batch 800/1563                   Loss Discriminator: -0.457, loss Generator: 0.183
# Epoch [30/50] Batch 900/1563                   Loss Discriminator: -0.337, loss Generator: -0.141
# Epoch [30/50] Batch 1000/1563                   Loss Discriminator: -0.478, loss Generator: 0.423
# Epoch [30/50] Batch 1100/1563                   Loss Discriminator: -0.466, loss Generator: 0.395
# Epoch [30/50] Batch 1200/1563                   Loss Discriminator: -0.395, loss Generator: 0.276
# Epoch [30/50] Batch 1300/1563                   Loss Discriminator: -0.414, loss Generator: 0.396
# Epoch [30/50] Batch 1400/1563                   Loss Discriminator: -0.465, loss Generator: 0.523
# Epoch [30/50] Batch 1500/1563                   Loss Discriminator: -0.378, loss Generator: 0.351
# Fretchet Distance:  284.8260157865212
# Epoch [31/50] Batch 0/1563                   Loss Discriminator: -0.452, loss Generator: 0.396
# Epoch [31/50] Batch 100/1563                   Loss Discriminator: -0.411, loss Generator: -0.098
# Epoch [31/50] Batch 200/1563                   Loss Discriminator: -0.458, loss Generator: 0.464
# Epoch [31/50] Batch 300/1563                   Loss Discriminator: -0.443, loss Generator: 0.431
# Epoch [31/50] Batch 400/1563                   Loss Discriminator: -0.382, loss Generator: 0.268
# Epoch [31/50] Batch 500/1563                   Loss Discriminator: -0.432, loss Generator: 0.194
# Epoch [31/50] Batch 600/1563                   Loss Discriminator: -0.399, loss Generator: 0.324
# Epoch [31/50] Batch 700/1563                   Loss Discriminator: -0.341, loss Generator: 0.395
# Epoch [31/50] Batch 800/1563                   Loss Discriminator: -0.500, loss Generator: 0.524
# Epoch [31/50] Batch 900/1563                   Loss Discriminator: -0.359, loss Generator: 0.487
# Epoch [31/50] Batch 1000/1563                   Loss Discriminator: -0.453, loss Generator: 0.460
# Epoch [31/50] Batch 1100/1563                   Loss Discriminator: -0.259, loss Generator: 0.341
# Epoch [31/50] Batch 1200/1563                   Loss Discriminator: -0.369, loss Generator: 0.385
# Epoch [31/50] Batch 1300/1563                   Loss Discriminator: -0.493, loss Generator: 0.246
# Epoch [31/50] Batch 1400/1563                   Loss Discriminator: -0.474, loss Generator: -0.027
# Epoch [42/50] Batch 1500/1563                   Loss Discriminator: -0.245, loss Generator: 0.153
# Fretchet Distance:  293.18008677945534
# Epoch [43/50] Batch 0/1563                   Loss Discriminator: -0.323, loss Generator: 0.287
# Epoch [43/50] Batch 100/1563                   Loss Discriminator: -0.332, loss Generator: 0.206
# Epoch [43/50] Batch 200/1563                   Loss Discriminator: -0.356, loss Generator: 0.356
# Epoch [43/50] Batch 300/1563                   Loss Discriminator: -0.306, loss Generator: 0.177
# Epoch [43/50] Batch 400/1563                   Loss Discriminator: -0.258, loss Generator: 0.292
# Epoch [43/50] Batch 500/1563                   Loss Discriminator: -0.323, loss Generator: 0.051
# Epoch [43/50] Batch 600/1563                   Loss Discriminator: -0.303, loss Generator: 0.242
# Epoch [43/50] Batch 700/1563                   Loss Discriminator: -0.402, loss Generator: 0.402
# Epoch [43/50] Batch 800/1563                   Loss Discriminator: -0.273, loss Generator: 0.213
# Epoch [43/50] Batch 900/1563                   Loss Discriminator: -0.320, loss Generator: 0.195
# Epoch [43/50] Batch 1000/1563                   Loss Discriminator: -0.284, loss Generator: 0.206
# Epoch [43/50] Batch 1100/1563                   Loss Discriminator: -0.173, loss Generator: 0.085
# Epoch [43/50] Batch 1200/1563                   Loss Discriminator: -0.037, loss Generator: 0.249
# Epoch [43/50] Batch 1300/1563                   Loss Discriminator: -0.282, loss Generator: 0.228
# Epoch [43/50] Batch 1400/1563                   Loss Discriminator: -0.225, loss Generator: 0.287
# Epoch [43/50] Batch 1500/1563                   Loss Discriminator: -0.297, loss Generator: 0.334
# Fretchet Distance:  302.6830787612512
# Epoch [44/50] Batch 0/1563                   Loss Discriminator: -0.261, loss Generator: 0.253
# Epoch [44/50] Batch 100/1563                   Loss Discriminator: -0.230, loss Generator: 0.116
# Epoch [44/50] Batch 200/1563                   Loss Discriminator: -0.205, loss Generator: 0.067

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(GenLoss,label="Gen")
plt.plot(DiscLoss,label="Disc")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()
